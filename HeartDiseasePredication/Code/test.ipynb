# %%
import pytest
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

def test_model_training_runs():
   df = pd.read_csv("../Data/processed/heart_disease_scaled.csv")

   X = df.drop(columns=['heart_disease_present'])
   y = df['heart_disease_present']

   model = train_model(X, y)
   assert model is not None 

def test_prediction_output_shape():
    sample = pd.read_csv("../Data/processed/heart_disease_scaled.csv")

    result = predict(sample)
    assert len(result) == 2 


def test_accuracy_above_baseline():
  
    df = pd.read_csv("../Data/processed/heart_disease_scaled.csv")

    X = df.drop(columns=['heart_disease_present'])
    y = df['heart_disease_present']


    model = train_model(X, y)
    preds = model.predict(X)
    acc = accuracy_score(y, preds)

    assert acc > 0.5 

def test_invalid_input_raises_error():
    with pytest.raises(Exception):
        predict("bad input")

# %%
import pytest
import pandas as pd

@pytest.fixture
def sample_data():
    return  pd.read_csv("../Data/processed/heart_disease_scaled.csv")

# %%
def test_model_with_fixture(sample_data):
    X = sample_data.drop(columns=['heart_disease_present'])
    y = sample_data['heart_disease_present']

    model = train_model(X, y)
    assert model is not None
